# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = [1,2,3,4,5]
y = [5,4,3,2,1]

# %% [markdown]
# Comments, does this work?
#
# Meow

# %% [markdown]
# # HI THERE

# %%
plt.plot(x,y)
